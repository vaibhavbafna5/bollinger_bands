# %%
from super_trend_lib import SuperTrendRunner
import pymongo

client = pymongo.MongoClient("mongodb+srv://new_user:new_user@super-trend.xltbo.mongodb.net/?retryWrites=true&w=majority")
db = client['super-trend']

# %%
db['VTI'].delete_many({})

# %%
JSON_PATH = '/root/projects/supertrend'
super_trend_runner = SuperTrendRunner(ticker='VTI', json_path=JSON_PATH, multiplier=2.5, debug_mode=True, rolling_period=14, initial_amount=10000)
super_trend_df = super_trend_runner.initialize_dataframe()
super_trend_df
# Out:
# generating super trend for VTI starting 2022-07-07 00:00:00 and ending 2023-01-06 00:00:00
#                   Open        High         Low       Close   Volume  \
# Date
# 2022-07-07  190.895315  193.461988  190.855667  193.075500  2919300
# 2022-07-08  192.312445  193.937676  191.271898  192.877319  2799200
# 2022-07-11  191.638579  192.005242  190.082710  190.439468  3033800
# 2022-07-12  190.271006  191.499845  187.892625  188.794418  2640300
# 2022-07-13  186.098899  189.369184  185.702507  187.971878  3322400
# ...                ...         ...         ...         ...      ...
# 2022-12-30  190.179993  191.270004  189.279999  191.190002  5978800
# 2023-01-03  192.380005  193.360001  188.929993  190.410004  4092500
# 2023-01-04  191.509995  193.059998  190.139999  192.100006  3852500
# 2023-01-05  191.220001  191.270004  189.460007  189.850006  4149000
# 2023-01-06  191.119995  193.589996  189.860001  193.544998  2303384
#
#             Dividends  Stock Splits  high-low  Previous Close  \
# Date
# 2022-07-07        0.0             0  2.606321      189.943970
# 2022-07-08        0.0             0  2.665778      193.075500
# 2022-07-11        0.0             0  1.922532      192.877319
# 2022-07-12        0.0             0  3.607221      190.439468
# 2022-07-13        0.0             0  3.666678      188.794418
# ...               ...           ...       ...             ...
# 2022-12-30        0.0             0  1.990005      191.679993
# 2023-01-03        0.0             0  4.430008      191.190002
# 2023-01-04        0.0             0  2.919998      190.410004
# 2023-01-05        0.0             0  1.809998      192.100006
# 2023-01-06        0.0             0  3.729996      189.850006
#
#             high-previous_close  ...  average_true_range  high_low_avg  \
# Date                             ...
# 2022-07-07             3.518018  ...                 NaN    192.158827
# 2022-07-08             0.862175  ...                 NaN    192.604787
# 2022-07-11            -0.872077  ...                 NaN    191.043976
# 2022-07-12             1.060377  ...                 NaN    189.696235
# 2022-07-13             0.574766  ...                 NaN    187.535846
# ...                         ...  ...                 ...           ...
# 2022-12-30            -0.409988  ...            3.304510    190.275002
# 2023-01-03             2.169998  ...            3.419765    191.144997
# 2023-01-04             2.649994  ...            3.194713    191.599998
# 2023-01-05            -0.830002  ...            3.007666    190.365005
# 2023-01-06             3.739990  ...            3.016056    191.724998
#
#             lower_band  higher_band  super_trend  final_higher_band  \
# Date
# 2022-07-07         NaN          NaN          NaN                NaN
# 2022-07-08         NaN          NaN          NaN                NaN
# 2022-07-11         NaN          NaN          NaN                NaN
# 2022-07-12         NaN          NaN          NaN                NaN
# 2022-07-13         NaN          NaN          NaN                NaN
# ...                ...          ...          ...                ...
# 2022-12-30  182.013727   198.536276   197.776727         197.776727
# 2023-01-03  182.595584   199.694409   197.776727         197.776727
# 2023-01-04  183.613217   199.586780   197.776727         197.776727
# 2023-01-05  182.845840   197.884171   197.776727         197.776727
# 2023-01-06  184.184858   199.265139   197.776727         197.776727
#
#             final_lower_band  buy_or_sell  portfolio_values percentage_change
# Date
# 2022-07-07               NaN         None      10000.000000               0.0
# 2022-07-08               NaN         None      10000.000000               0.0
# 2022-07-11               NaN         None      10000.000000               0.0
# 2022-07-12               NaN         None      10000.000000               0.0
# 2022-07-13               NaN         None      10000.000000               0.0
# ...                      ...          ...               ...               ...
# 2022-12-30        184.295412        False      10212.168584               0.0
# 2023-01-03        184.295412        False      10212.168584               0.0
# 2023-01-04        184.295412        False      10212.168584               0.0
# 2023-01-05        184.295412        False      10212.168584               0.0
# 2023-01-06        184.295412        False      10212.168584               0.0
#
# [128 rows x 22 columns]

# %%
super_trend_runner.write_initial_dataframe_to_mongo(super_trend_df)

# %%
trade_data = super_trend_runner.read_trade_data_from_mongo_to_dataframe()
trade_data.tail(5)
# Out:
#                           _id       Date        Open        High         Low  \
# 123  63b73f3f7cb8be1942f9323a 2022-12-30  190.179993  191.270004  189.279999
# 124  63b73f3f7cb8be1942f9323b 2023-01-03  192.380005  193.360001  188.929993
# 125  63b73f3f7cb8be1942f9323c 2023-01-04  191.509995  193.059998  190.139999
# 126  63b73f3f7cb8be1942f9323d 2023-01-05  191.220001  191.220001  189.460007
# 127  63b7d506d135f1d8c42d7e1f 2023-01-05  191.220001  191.270004  189.460007
#
#           Close   Volume  Dividends  Stock Splits  high-low  ...  \
# 123  191.190002  5978800        0.0             0  1.990005  ...
# 124  190.410004  4092500        0.0             0  4.430008  ...
# 125  192.100006  3852500        0.0             0  2.919998  ...
# 126  189.850006  4023523        0.0             0  1.759995  ...
# 127  189.850006  4149000        0.0             0  1.809998  ...
#
#      average_true_range  high_low_avg  lower_band  higher_band  super_trend  \
# 123            3.304510    190.275002  182.013727   198.536276   197.776727
# 124            3.419765    191.144997  182.595584   199.694409   197.776727
# 125            3.194713    191.599998  183.613217   199.586780   197.776727
# 126            3.004095    190.340004  182.829767   197.850241   197.776727
# 127            3.007666    190.365005  182.845840   197.884171   197.776727
#
#      final_higher_band  final_lower_band  buy_or_sell  portfolio_values  \
# 123         197.776727        184.295412        False      10212.168634
# 124         197.776727        184.295412        False      10212.168634
# 125         197.776727        184.295412        False      10212.168634
# 126         197.776727        184.295412        False      10212.168634
# 127         197.776727        184.295412        False      10212.168584
#
#      percentage_change
# 123                0.0
# 124                0.0
# 125                0.0
# 126                0.0
# 127                0.0
#
# [5 rows x 24 columns]

# %%
import smtplib, ssl
from email.message import EmailMessage
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText

# %%
receiver_email = "vbafna@umich.edu"
sender_email = "vaibhavbafna5@proton.me"
password = "@Collingsworth5"

port_number = 587
msg = MIMEMultipart()
msg['From'] = sender_email
msg['To'] = receiver_email
msg['Subject'] = "Trade Decision"
message = "hello mr. paneer"
msg.attach(MIMEText(message))
mailserver = smtplib.SMTP('localhost', port_number)
mailserver.login(sender_email, password)
mailserver.sendmail(sender_email, receiver_email, msg.as_string())
mailserver.quit()


# msg = EmailMessage()
# body = "hello mr. paneer"

# msg['Subject'] = "Trade Decision"
# msg['From'] = sender_email
# msg['To'] = receiver_email

# context = ssl.create_default_context()
# with smtplib.SMTP(smtp_server, port) as server:
#     server.ehlo()
#     server.starttls(context=context)
#     server.login("vaibhavbafna5@proton.me", password)
#     server.send_message(msg)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In [8], line 12
#      10 message = "hello mr. paneer"
#      11 msg.attach(MIMEText(message))
# ---> 12 mailserver = smtplib.SMTP('localhost', port_number)
#      13 mailserver.login(sender_email, password)
#      14 mailserver.sendmail(sender_email, receiver_email, msg.as_string())
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/smtplib.py:253, in SMTP.__init__(self, host, port, local_hostname, timeout, source_address)
#     250 self.source_address = source_address
#     252 if host:
# --> 253     (code, msg) = self.connect(host, port)
#     254     if code != 220:
#     255         self.close()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/smtplib.py:339, in SMTP.connect(self, host, port, source_address)
#     337     self._print_debug('connect:', (host, port))
#     338 sys.audit("smtplib.connect", self, host, port)
# --> 339 self.sock = self._get_socket(host, port, self.timeout)
#     340 self.file = None
#     341 (code, msg) = self.getreply()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/smtplib.py:308, in SMTP._get_socket(self, host, port, timeout)
#     306 if self.debuglevel > 0:
#     307     self._print_debug('connect: to', (host, port), self.source_address)
# --> 308 return socket.create_connection((host, port), timeout,
#     309                                 self.source_address)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/socket.py:808, in create_connection(address, timeout, source_address)
#     806 if err is not None:
#     807     try:
# --> 808         raise err
#     809     finally:
#     810         # Break explicitly a reference cycle
#     811         err = None
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/socket.py:796, in create_connection(address, timeout, source_address)
#     794 if source_address:
#     795     sock.bind(source_address)
# --> 796 sock.connect(sa)
#     797 # Break explicitly a reference cycle
#     798 err = None
#
# ConnectionRefusedError: [Errno 61] Connection refused
