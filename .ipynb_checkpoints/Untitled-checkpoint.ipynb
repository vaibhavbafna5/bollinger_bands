# %%
from super_trend_lib import SuperTrendRunner

# %%
JSON_PATH = '/root/projects/supertrend'

vti_runner = SuperTrendRunner(ticker='VTI', json_path=JSON_PATH, multiplier=2.5, debug_mode=True, rolling_period=14, initial_amount=10000)
res = vti_runner.generate_trade_signal()

# %%
res.tail(5)
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2022-12-28  190.649994  191.500000  188.059998  188.220001  5711900
# 2022-12-29  189.490005  192.160004  189.369995  191.679993  5425700
# 2022-12-30  190.179993  191.270004  189.279999  191.190002  5978800
# 2023-01-03  192.380005  193.360001  188.929993  190.410004  4092500
# 2023-01-04  191.509995  193.039993  190.139999  192.029999  3398962
#
#             Dividends  Stock Splits  high-low  Previous Close  \
# Date
# 2022-12-28        0.0             0  3.440002      190.619995
# 2022-12-29        0.0             0  2.790009      188.220001
# 2022-12-30        0.0             0  1.990005      191.679993
# 2023-01-03        0.0             0  4.430008      191.190002
# 2023-01-04        0.0             0  2.899994      190.410004
#
#             high-previous_close  ...  average_true_range  high_low_avg  \
# Date                             ...
# ...

# %%
import pymongo

# %%
# client = pymongo.MongoClient("mongodb+srv://covid-dashboard-admin:<covid-dashboard-admin>@super-trend.xltbo.mongodb.net/?retryWrites=true&w=majority", authSource="admin")

# %%
# client = pymongo.MongoClient("mongodb+srv://covid-dashboard-admin:<covid-dashboard-admin>@super-trend.xltbo.mongodb.net/?retryWrites=true&w=majority")
# db = client['super-trend']
# collection = db['VTI']

# %%
collection
# Out:
# Collection(Database(MongoClient(host=['super-trend-shard-00-02.xltbo.mongodb.net:27017', 'super-trend-shard-00-01.xltbo.mongodb.net:27017', 'super-trend-shard-00-00.xltbo.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-1ythfq-shard-0', tls=True), 'super-trend'), 'VTI')

# %%
client = pymongo.MongoClient("mongodb+srv://<new_user>:<new_user>@super-trend.xltbo.mongodb.net/?retryWrites=true&w=majority")
db = client['super-trend']
collection = db['VTI']

# %%
res.reset_index(inplace=True)
res.tail(5)
# Out:
#           Date        Open        High         Low       Close   Volume  \
# 122 2022-12-28  190.649994  191.500000  188.059998  188.220001  5711900
# 123 2022-12-29  189.490005  192.160004  189.369995  191.679993  5425700
# 124 2022-12-30  190.179993  191.270004  189.279999  191.190002  5978800
# 125 2023-01-03  192.380005  193.360001  188.929993  190.410004  4092500
# 126 2023-01-04  191.509995  193.039993  190.139999  192.029999  3398962
#
#      Dividends  Stock Splits  high-low  Previous Close  ...  \
# 122        0.0             0  3.440002      190.619995  ...
# 123        0.0             0  2.790009      188.220001  ...
# 124        0.0             0  1.990005      191.679993  ...
# 125        0.0             0  4.430008      191.190002  ...
# 126        0.0             0  2.899994      190.410004  ...
#
#      average_true_range  high_low_avg  lower_band  higher_band  super_trend  \
# 122            3.198691    189.779999  181.783270   197.776727   197.776727
# ...

# %%
values = list(res.T.to_dict().values())
values
# Out:
# [{'Date': Timestamp('2022-07-06 00:00:00'),
#   'Open': 189.56738686723958,
#   'High': 191.16288908518612,
#   'Low': 188.1700957045454,
#   'Close': 189.9439697265625,
#   'Volume': 2981000,
#   'Dividends': 0.0,
#   'Stock Splits': 0,
#   'high-low': 2.992793380640734,
#   'Previous Close': 189.5673828125,
#   'high-previous_close': 1.5955062726861229,
#   'low-previous_close': -1.397287107954611,
#   'true_range': 2.992793380640734,
#   'average_true_range': nan,
#   'high_low_avg': 189.66649239486577,
#   'lower_band': nan,
#   'higher_band': nan,
#   'super_trend': nan,
#   'final_higher_band': nan,
#   'final_lower_band': nan,
#   'buy_or_sell': None,
#   'portfolio_values': 10000.0,
#   'percentage_change': 0.0},
#  {'Date': Timestamp('2022-07-07 00:00:00'),
#   'Open': 190.89531515818572,
#   'High': 193.46198781897374,
#   'Low': 190.85566690195208,
#   'Close': 193.07550048828125,
#   'Volume': 2919300,
#   'Dividends': 0.0,
#   'Stock Splits': 0,
# ...

# %%
collection.insert_many(values)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 collection.insert_many(values)
#
# File ~/projects/super_trend/venv/lib/python3.8/site-packages/pymongo/_csot.py:105, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     103         with _TimeoutContext(timeout):
#     104             return func(self, *args, **kwargs)
# --> 105 return func(self, *args, **kwargs)
#
# File ~/projects/super_trend/venv/lib/python3.8/site-packages/pymongo/collection.py:714, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     712 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     713 blk.ops = [doc for doc in gen()]
# --> 714 blk.execute(write_concern, session=session)
#     715 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# ...
