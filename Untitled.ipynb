# %%
from super_trend_lib import SuperTrendRunner
import pymongo

client = pymongo.MongoClient("mongodb+srv://new_user:new_user@super-trend.xltbo.mongodb.net/?retryWrites=true&w=majority")
db = client['super-trend']

# %%
db['VTI'].delete_many({})

# %%
JSON_PATH = '/root/projects/supertrend'
super_trend_runner = SuperTrendRunner(ticker='VTI', json_path=JSON_PATH, multiplier=2.5, debug_mode=True, rolling_period=14, initial_amount=10000)
super_trend_df = super_trend_runner.initialize_dataframe()
super_trend_df
# Out:
# generating super trend for VTI starting 2022-07-12 00:00:00 and ending 2023-01-10 00:00:00
#                   Open        High         Low       Close   Volume  \
# Date
# 2022-07-12  190.271006  191.499845  187.892625  188.794418  2640300
# 2022-07-13  186.098899  189.369184  185.702507  187.971878  3322400
# 2022-07-14  185.593501  187.486304  183.908813  187.139450  3355600
# 2022-07-15  189.468292  190.816046  188.269182  190.776398  2914600
# 2022-07-18  192.540368  193.016057  188.824138  189.458374  3974200
# ...                ...         ...         ...         ...      ...
# 2023-01-04  191.509995  193.059998  190.139999  192.100006  3852500
# 2023-01-05  191.220001  191.270004  189.460007  189.850006  4150000
# 2023-01-06  191.119995  194.639999  189.850006  194.039993  3182100
# 2023-01-09  195.460007  196.889999  194.009995  194.119995  3888300
# 2023-01-10  193.649994  195.639999  193.289993  195.630005  2604177
#
#             Dividends  Stock Splits  high-low  Previous Close  \
# Date
# 2022-07-12        0.0             0  3.607221      190.439468
# 2022-07-13        0.0             0  3.666678      188.794418
# 2022-07-14        0.0             0  3.577492      187.971878
# 2022-07-15        0.0             0  2.546864      187.139450
# 2022-07-18        0.0             0  4.191919      190.776398
# ...               ...           ...       ...             ...
# 2023-01-04        0.0             0  2.919998      190.410004
# 2023-01-05        0.0             0  1.809998      192.100006
# 2023-01-06        0.0             0  4.789993      189.850006
# 2023-01-09        0.0             0  2.880005      194.039993
# 2023-01-10        0.0             0  2.350006      194.119995
#
#             high-previous_close  ...  average_true_range  high_low_avg  \
# Date                             ...
# 2022-07-12             1.060377  ...                 NaN    189.696235
# 2022-07-13             0.574766  ...                 NaN    187.535846
# 2022-07-14            -0.485574  ...                 NaN    185.697558
# 2022-07-15             3.676596  ...                 NaN    189.542614
# 2022-07-18             2.239659  ...                 NaN    190.920097
# ...                         ...  ...                 ...           ...
# 2023-01-04             2.649994  ...            3.194713    191.599998
# 2023-01-05            -0.830002  ...            3.007666    190.365005
# 2023-01-06             4.789993  ...            3.091056    192.245003
# 2023-01-09             2.850006  ...            3.097730    195.449997
# 2023-01-10             1.520004  ...            3.054463    194.464996
#
#             lower_band  higher_band  super_trend  final_higher_band  \
# Date
# 2022-07-12         NaN          NaN          NaN                NaN
# 2022-07-13         NaN          NaN          NaN                NaN
# 2022-07-14         NaN          NaN          NaN                NaN
# 2022-07-15         NaN          NaN          NaN                NaN
# 2022-07-18         NaN          NaN          NaN                NaN
# ...                ...          ...          ...                ...
# 2023-01-04  183.613217   199.586780   197.776727         197.776727
# 2023-01-05  182.845840   197.884171   197.776727         197.776727
# 2023-01-06  184.517362   199.972643   197.776727         197.776727
# 2023-01-09  187.705671   203.194323   197.776727         197.776727
# 2023-01-10  186.828839   202.101153   197.776727         197.776727
#
#             final_lower_band  buy_or_sell  portfolio_values percentage_change
# Date
# 2022-07-12               NaN         None      10000.000000               0.0
# 2022-07-13               NaN         None      10000.000000               0.0
# 2022-07-14               NaN         None      10000.000000               0.0
# 2022-07-15               NaN         None      10000.000000               0.0
# 2022-07-18               NaN         None      10000.000000               0.0
# ...                      ...          ...               ...               ...
# 2023-01-04        184.295412        False      10065.003664               0.0
# 2023-01-05        184.295412        False      10065.003664               0.0
# 2023-01-06        184.517362        False      10065.003664               0.0
# 2023-01-09        187.705671        False      10065.003664               0.0
# 2023-01-10        187.705671        False      10065.003664               0.0
#
# [127 rows x 22 columns]

# %%
super_trend_runner.send_trade_decision_via_email('merp')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/projects/super_trend/super_trend_lib.py:491, in SuperTrendRunner.send_trade_decision_via_email(self, trade_decision)
#     490 server.starttls(context=context)
# --> 491 server.login(sender_email, password)
#     492 server.send_message(msg)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/smtplib.py:723, in SMTP.login(self, user, password, initial_response_ok)
#     722 try:
# --> 723     (code, resp) = self.auth(
#     724         authmethod, getattr(self, method_name),
#     725         initial_response_ok=initial_response_ok)
#     726     # 235 == 'Authentication successful'
#     727     # 503 == 'Error: already authenticated'
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/smtplib.py:642, in SMTP.auth(self, mechanism, authobject, initial_response_ok)
#     640 challenge = base64.decodebytes(resp)
#     641 response = encode_base64(
# --> 642     authobject(challenge).encode('ascii'), eol='')
#     643 (code, resp) = self.docmd(response)
#
# AttributeError: 'NoneType' object has no attribute 'encode'
#
# During handling of the above exception, another exception occurred:
#
# SMTPResponseException                     Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 super_trend_runner.send_trade_decision_via_email('merp')
#
# File ~/projects/super_trend/super_trend_lib.py:492, in SuperTrendRunner.send_trade_decision_via_email(self, trade_decision)
#     490 server.starttls(context=context)
#     491 server.login(sender_email, password)
# --> 492 server.send_message(msg)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/smtplib.py:282, in SMTP.__exit__(self, *args)
#     280     code, message = self.docmd("QUIT")
#     281     if code != 221:
# --> 282         raise SMTPResponseException(code, message)
#     283 except SMTPServerDisconnected:
#     284     pass
#
# SMTPResponseException: (535, b'5.7.8 Username and Password not accepted. Learn more at\n5.7.8  https://support.google.com/mail/?p=BadCredentials e5-20020ac86705000000b003a611cb2a95sm922457qtp.9 - gsmtp')

# %%
trade_data = super_trend_runner.read_trade_data_from_mongo_to_dataframe()
trade_data.tail(5)
# Out:
#                         _id       Date        Open        High         Low  \
# 0  63bbc9871598eb17f4662b7d 2023-01-06  191.119995  194.639999  189.850006
# 1  63bd1b08ea0577425b413e48 2023-01-09  195.460007  196.889999  194.009995
#
#         Close   Volume  Dividends  Stock Splits  high-low  ...  \
# 0  194.039993  3182100        0.0             0  4.789993  ...
# 1  194.119995  3886800        0.0             0  2.880005  ...
#
#    average_true_range  high_low_avg  lower_band  higher_band  super_trend  \
# 0            3.091056    192.245003  184.517362   199.972643   197.776727
# 1            3.097730    195.449997  187.705671   203.194323   197.776727
#
#    final_higher_band  final_lower_band  buy_or_sell  portfolio_values  \
# 0         197.776727        184.517362        False      10212.168584
# 1         197.776727        187.705671        False      10065.003664
#
#    percentage_change
# 0                0.0
# 1                0.0
#
# [2 rows x 24 columns]

# %%
import smtplib, ssl
from email.message import EmailMessage
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText

# %%
receiver_email = "vbafna@umich.edu"
sender_email = "vbafna@umich.edu"
password = "@Collingsworth5"

port = 587
smtp_server = "smtp.gmail.com"

msg = EmailMessage()
body = "hello mr. paneer"
msg.set_content(body)

msg['Subject'] = "Trade Decision"
msg['From'] = sender_email
msg['To'] = receiver_email

context = ssl.create_default_context()
with smtplib.SMTP(smtp_server, port) as server:
    server.ehlo()
    server.starttls(context=context)
    server.login(sender_email, password)
    server.send_message(msg)
