# %%
from super_trend_lib import SuperTrendRunner

import psycopg2

# %%
from sqlalchemy import create_engine
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 from sqlalchemy import create_engine
#
# File ~/projects/super_trend/venv/lib/python3.9/site-packages/sqlalchemy/__init__.py:8
#       1 # sqlalchemy/__init__.py
#       2 # Copyright (C) 2005-2022 the SQLAlchemy authors and contributors
#       3 # <see AUTHORS file>
#       4 #
#       5 # This module is part of SQLAlchemy and is released under
#       6 # the MIT License: https://www.opensource.org/licenses/mit-license.php
# ----> 8 from . import util as _util
#       9 from .engine import create_engine
#      10 from .engine import create_mock_engine
#
# File ~/projects/super_trend/venv/lib/python3.9/site-packages/sqlalchemy/util/__init__.py:14
#      11 from functools import partial
#      12 from functools import update_wrapper
# ---> 14 from ._collections import coerce_generator_arg
# ...

# %%
username = 'doadmin'
password = 'AVNS_7UdRdYMTbEvLTdtW-gj'
host = 'db-postgresql-nyc1-69812-do-user-12573685-0.b.db.ondigitalocean.com'
port = '25060'
database = 'defaultdb'
sslmode = 'require'

# %%
#establishing the connection
conn = psycopg2.connect(
   database=database, user=username, password=password, host=host, port=port
)
#Creating a cursor object using the cursor() method
cursor = conn.cursor()

# %%
cursor.execute('DROP TABLE IF EXISTS books;')

# %%
cursor.close()

# %%
runner = SuperTrendRunner('VGT', debug_mode=True)
super_trend_df = runner.run()
# Out:
# generating super trend for VGT starting 2004-02-02 00:00:00 and ending 2022-10-04 00:00:00
#                   Open        High         Low       Close   Volume  \
# Date
# 2022-09-14  342.176921  343.962634  338.685320  342.067200   439000
# 2022-09-15  339.084355  341.698063  332.570026  334.455505   583100
# 2022-09-16  331.033732  332.450338  327.402483  331.951538   706500
# 2022-09-19  328.789108  334.814623  328.699328  334.555237  2702100
# 2022-09-20  331.372933  334.714870  329.706927  332.480255   472200
# 2022-09-21  334.056448  339.184128  327.442383  327.442383   501300
# 2022-09-22  325.856212  327.073255  321.506658  323.132751   730500
# 2022-09-23  320.159894  320.738519  314.573326  318.553772  2603200
# 2022-09-26  317.865408  323.471918  315.620808  316.478729  1130200
# 2022-09-27  320.778404  323.950797  314.443666  317.616028  2315900
# 2022-09-28  315.339996  322.859985  313.459991  321.299988  1424400
# ...

# %%
super_trend_df.tail(10)

# %%
i = len(super_trend_df.index) - 1
recent = None
while i > 0:
    current = super_trend_df.iloc[i]
    previous = super_trend_df.iloc[i - 1]
    
    
    
    percent_change = (100 + current['percentage_change']) / 100
    calculated = current['portfolio_values'] / percent_change
    original = previous['portfolio_values']
    
    if calculated == original:
        print("valid")
    else:
        print("invalid")
        print(f'calc: {calculated}')
        print(f'orig: {original}')
    i -= 1
# Out:
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# invalid
# calc: 21760.90413138961
# orig: 21760.904131389612
# invalid
# calc: 20899.65498388527
# orig: 20899.654983885266
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# invalid
# calc: 20412.101385404712
# orig: 20412.10138540471
# valid
# valid
# valid
# valid
# invalid
# calc: 18905.44547928244
# orig: 18905.445479282444
# invalid
# calc: 19343.1681259657
# orig: 19343.168125965705
# invalid
# calc: 19486.908512266
# orig: 19486.908512266004
# valid
# invalid
# calc: 20835.553400437802
# orig: 20835.5534004378
# valid
# invalid
# calc: 20654.85011293227
# orig: 20654.850112932265
# valid
# valid
# invalid
# calc: 19066.953182564834
# orig: 19066.95318256483
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# valid
# ...

# %%
super_trend_df.head(5)
# Out:
#              Open   High   Low  Close     Volume  Dividends  Stock Splits  \
# Date
# 2020-10-01   9.69  10.10  9.23   9.46  124297600          0             0
# 2020-10-02   9.06   9.28  8.94   9.20   55018300          0             0
# 2020-10-05   9.43   9.49  8.92   9.03   36316900          0             0
# 2020-10-06   9.04  10.18  8.90   9.90   90864000          0             0
# 2020-10-07  10.04  10.49  9.99  10.00   54672400          0             0
#
#             high-low  Previous Close  high-previous_close  ...  \
# Date                                                       ...
# 2020-10-01  0.870001            9.50             0.600000  ...
# 2020-10-02  0.340000            9.46            -0.180000  ...
# 2020-10-05  0.570000            9.20             0.290000  ...
# 2020-10-06  1.280001            9.03             1.150001  ...
# 2020-10-07  0.500000            9.90             0.590000  ...
#
# ...
