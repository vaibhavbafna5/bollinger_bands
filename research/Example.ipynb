# %%
# need to do these shenanigans since our "package" is technically stored in another folder
import sys
import os

module_path = os.path.abspath(os.path.join('..', 'src'))

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from super_trend_lib import SuperTrendRunner

vgt_runner = SuperTrendRunner(ticker='VGT', debug_mode=True)
vgt_runner.explore(period="3y")
# Out:
# [2024-04-08 12:00:32] [INFO] [Generating super trend for VGT starting 2021-04-09 00:00:00-04:00 and ending 2024-04-08 00:00:00-04:00] [super_trend_lib.py:63]
#                                  Open        High  ...  final_lower_band  buy_or_sell
# Date                                               ...
# 2024-03-18 00:00:00-04:00  519.440104  522.552669  ...        509.988289         True
# 2024-03-19 00:00:00-04:00  513.524198  519.759315  ...        509.988289         True
# 2024-03-20 00:00:00-04:00  520.018709  526.064276  ...        509.988289         True
# 2024-03-21 00:00:00-04:00  532.688463  532.688463  ...        509.988289         True
# 2024-03-22 00:00:00-04:00  527.179993  530.150024  ...        509.988289         True
# 2024-03-25 00:00:00-04:00  523.500000  528.729980  ...        509.988289         True
# 2024-03-26 00:00:00-04:00  528.640015  529.109985  ...        509.988289         True
# ...
